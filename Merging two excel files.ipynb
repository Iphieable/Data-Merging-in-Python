# %%
# importing the python pandas library to work with
import pandas as pd

# %%
# reading one of the two excel .csv files
pd.read_csv("Capstone_Project.csv")
# Out:
#      Year         Q1         Q2         Q3         Q4       Q1milU  \
# 0    2008   2.320000   1.700000   0.720000   6.890000   2320000.00
# 1    2009   4.360000   3.790000   5.210000   7.370000   4360000.00
# 2    2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# 3    2011  16.240000  18.650000  20.340000  17.070000  16240000.00
# 4    2012  37.040000  35.060000  26.030000  26.910000  37040000.00
# ..    ...        ...        ...        ...        ...          ...
# 636  2014  15.871714  13.598106  10.948155  12.214035  15871714.10
# 637  2015  29.962663  24.611469  19.123478  19.332697  29962663.11
# 638  2016  26.858792  18.385953  14.424299  16.345863  26858792.25
# 639  2017  33.860744  21.953907  17.745642  20.189290  33860744.29
# 640  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
#
#           Q2milU       Q3milU       Q4milU ModelMake  ... Unnamed: 19  \
# 0     1700000.00    720000.00   6890000.00     Apple  ...         NaN
# ...

# %%
# reading the second excel .csv files
pd.read_csv("MarketShare_Countries.csv")
# Out:
#     Year      Apple  Samsung    RIM   HTC  Nokia  SonyEricsson  Motorola  \
# 0   2010  46.010000     1.45  39.63  0.02   6.54          4.61      0.01
# 1   2011  43.900000     4.18  40.81  2.81   3.75          3.65      0.05
# 2   2012  46.740000    20.15  17.26  4.85   3.57          2.19      0.28
# 3   2013  43.390000    12.31  27.93  7.51   2.32          2.86      0.29
# 4   2014  44.980000    24.24  10.24  3.57   5.41          3.52      0.92
# ..   ...        ...      ...    ...   ...    ...           ...       ...
# 58  2010   0.674553     0.64   0.64  5.74   5.74          6.87      5.77
# 59  2010   0.703347     0.70   0.61  4.60   4.60          5.74      7.92
# 60  2010   0.665555     0.33   0.70  6.51   6.51          5.19      4.49
# 61  2010   0.735440     0.39   0.92  6.63   6.63          4.38      5.24
# 62  2010   0.763034     0.79   0.78  6.16   6.16          2.93      3.69
#
#     Google    LG  Unknown Country  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
# assigning dataframes to the two excel .csv files
df = pd.read_csv("Capstone_Project.csv")
df1 = pd.read_csv("MarketShare_Countries.csv")

# %%
# merging the two csv files on their common column, 'Year'
df2 = df.merge(df1, on="Year")
df2
# Out:
#       Year         Q1         Q2         Q3         Q4       Q1milU  \
# 0     2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# 1     2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# 2     2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# 3     2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# 4     2010   8.740000   8.750000   8.400000  14.100000   8740000.00
# ...    ...        ...        ...        ...        ...          ...
# 4468  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
# 4469  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
# 4470  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
# 4471  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
# 4472  2018  36.182964  24.437072  19.326906  21.942824  36182963.84
#
#            Q2milU       Q3milU       Q4milU ModelMake  ...     LG  Unknown  \
# ...
